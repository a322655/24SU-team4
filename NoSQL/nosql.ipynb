# %% [markdown]
# Run `docker-compose up -d` to start the services.

# %%
import json
import random


def generate_data(num_users=100):
    users = []
    for i in range(1, num_users + 1):
        user = {
            "id": i,
            "name": f"User{i}",
            "friends": []
        }
        users.append(user)

    for user in users:
        num_friends = random.randint(1, num_users // 2)
        friends = random.sample([u["id"] for u in users if u["id"] != user["id"]], num_friends)
        user["friends"] = friends

    data = {
        "users": users
    }

    return data


data = generate_data(100)

with open("data.json", "w") as f:
    json.dump(data, f, indent=2)

print("data.json file has been generated.")
# Out:
# data.json file has been generated.

# %%
import pymongo
import redis
from neo4j import GraphDatabase

client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["mydatabase"]
collection = db["users"]

r = redis.Redis(host='localhost', port=6379, db=0)

uri = "bolt://localhost:7687"
username = "neo4j"
password = "password"
driver = GraphDatabase.driver(uri, auth=(username, password))

# %%
with open("data.json") as file:
    data = json.load(file)

collection.insert_many(data["users"])
# Out:
# InsertManyResult([ObjectId('6659982fe37981682a4d2d78'), ObjectId('6659982fe37981682a4d2d79'), ObjectId('6659982fe37981682a4d2d7a'), ObjectId('6659982fe37981682a4d2d7b'), ObjectId('6659982fe37981682a4d2d7c'), ObjectId('6659982fe37981682a4d2d7d'), ObjectId('6659982fe37981682a4d2d7e'), ObjectId('6659982fe37981682a4d2d7f'), ObjectId('6659982fe37981682a4d2d80'), ObjectId('6659982fe37981682a4d2d81'), ObjectId('6659982fe37981682a4d2d82'), ObjectId('6659982fe37981682a4d2d83'), ObjectId('6659982fe37981682a4d2d84'), ObjectId('6659982fe37981682a4d2d85'), ObjectId('6659982fe37981682a4d2d86'), ObjectId('6659982fe37981682a4d2d87'), ObjectId('6659982fe37981682a4d2d88'), ObjectId('6659982fe37981682a4d2d89'), ObjectId('6659982fe37981682a4d2d8a'), ObjectId('6659982fe37981682a4d2d8b'), ObjectId('6659982fe37981682a4d2d8c'), ObjectId('6659982fe37981682a4d2d8d'), ObjectId('6659982fe37981682a4d2d8e'), ObjectId('6659982fe37981682a4d2d8f'), ObjectId('6659982fe37981682a4d2d90'), ObjectId('6659982fe37981682a4d2d91'), ObjectId('6659982fe37981682a4d2d92'), ObjectId('6659982fe37981682a4d2d93'), ObjectId('6659982fe37981682a4d2d94'), ObjectId('6659982fe37981682a4d2d95'), ObjectId('6659982fe37981682a4d2d96'), ObjectId('6659982fe37981682a4d2d97'), ObjectId('6659982fe37981682a4d2d98'), ObjectId('6659982fe37981682a4d2d99'), ObjectId('6659982fe37981682a4d2d9a'), ObjectId('6659982fe37981682a4d2d9b'), ObjectId('6659982fe37981682a4d2d9c'), ObjectId('6659982fe37981682a4d2d9d'), ObjectId('6659982fe37981682a4d2d9e'), ObjectId('6659982fe37981682a4d2d9f'), ObjectId('6659982fe37981682a4d2da0'), ObjectId('6659982fe37981682a4d2da1'), ObjectId('6659982fe37981682a4d2da2'), ObjectId('6659982fe37981682a4d2da3'), ObjectId('6659982fe37981682a4d2da4'), ObjectId('6659982fe37981682a4d2da5'), ObjectId('6659982fe37981682a4d2da6'), ObjectId('6659982fe37981682a4d2da7'), ObjectId('6659982fe37981682a4d2da8'), ObjectId('6659982fe37981682a4d2da9'), ObjectId('6659982fe37981682a4d2daa'), ObjectId('6659982fe37981682a4d2dab'), ObjectId('6659982fe37981682a4d2dac'), ObjectId('6659982fe37981682a4d2dad'), ObjectId('6659982fe37981682a4d2dae'), ObjectId('6659982fe37981682a4d2daf'), ObjectId('6659982fe37981682a4d2db0'), ObjectId('6659982fe37981682a4d2db1'), ObjectId('6659982fe37981682a4d2db2'), ObjectId('6659982fe37981682a4d2db3'), ObjectId('6659982fe37981682a4d2db4'), ObjectId('6659982fe37981682a4d2db5'), ObjectId('6659982fe37981682a4d2db6'), ObjectId('6659982fe37981682a4d2db7'), ObjectId('6659982fe37981682a4d2db8'), ObjectId('6659982fe37981682a4d2db9'), ObjectId('6659982fe37981682a4d2dba'), ObjectId('6659982fe37981682a4d2dbb'), ObjectId('6659982fe37981682a4d2dbc'), ObjectId('6659982fe37981682a4d2dbd'), ObjectId('6659982fe37981682a4d2dbe'), ObjectId('6659982fe37981682a4d2dbf'), ObjectId('6659982fe37981682a4d2dc0'), ObjectId('6659982fe37981682a4d2dc1'), ObjectId('6659982fe37981682a4d2dc2'), ObjectId('6659982fe37981682a4d2dc3'), ObjectId('6659982fe37981682a4d2dc4'), ObjectId('6659982fe37981682a4d2dc5'), ObjectId('6659982fe37981682a4d2dc6'), ObjectId('6659982fe37981682a4d2dc7'), ObjectId('6659982fe37981682a4d2dc8'), ObjectId('6659982fe37981682a4d2dc9'), ObjectId('6659982fe37981682a4d2dca'), ObjectId('6659982fe37981682a4d2dcb'), ObjectId('6659982fe37981682a4d2dcc'), ObjectId('6659982fe37981682a4d2dcd'), ObjectId('6659982fe37981682a4d2dce'), ObjectId('6659982fe37981682a4d2dcf'), ObjectId('6659982fe37981682a4d2dd0'), ObjectId('6659982fe37981682a4d2dd1'), ObjectId('6659982fe37981682a4d2dd2'), ObjectId('6659982fe37981682a4d2dd3'), ObjectId('6659982fe37981682a4d2dd4'), ObjectId('6659982fe37981682a4d2dd5'), ObjectId('6659982fe37981682a4d2dd6'), ObjectId('6659982fe37981682a4d2dd7'), ObjectId('6659982fe37981682a4d2dd8'), ObjectId('6659982fe37981682a4d2dd9'), ObjectId('6659982fe37981682a4d2dda'), ObjectId('6659982fe37981682a4d2ddb')], acknowledged=True)

# %%
def create_user(tx, user_id, name):
    tx.run("CREATE (u:User {id: $user_id, name: $name})", user_id=user_id, name=name)


def create_friendship(tx, user_id, friend_id):
    tx.run("""
        MATCH (u1:User {id: $user_id}), (u2:User {id: $friend_id})
        MERGE (u1)-[:FRIEND]->(u2)
        """, user_id=user_id, friend_id=friend_id)


with driver.session() as session:
    for user in data["users"]:
        session.execute_write(create_user, user["id"], user["name"])
        for friend_id in user["friends"]:
            session.execute_write(create_friendship, user["id"], friend_id)

# %%
def get_graph(tx):
    result = tx.run("MATCH (u:User)-[:FRIEND]-(f:User) RETURN u.name, f.name")
    for record in result:
        print(f"{record['u.name']} is friends with {record['f.name']}")


with driver.session() as session:
    session.execute_read(get_graph)
# Out:
# User95 is friends with User1
# User94 is friends with User1
# User92 is friends with User1
# User85 is friends with User1
# User82 is friends with User1
# User78 is friends with User1
# User75 is friends with User1
# User73 is friends with User1
# User71 is friends with User1
# User70 is friends with User1
# User63 is friends with User1
# User55 is friends with User1
# User52 is friends with User1
# User49 is friends with User1
# User44 is friends with User1
# User41 is friends with User1
# User38 is friends with User1
# User37 is friends with User1
# User31 is friends with User1
# User30 is friends with User1
# User23 is friends with User1
# User13 is friends with User1
# User12 is friends with User1
# User6 is friends with User1
# User2 is friends with User1
# User100 is friends with User2
# User95 is friends with User2
# User90 is friends with User2
# User89 is friends with User2
# User86 is friends with User2
# User85 is friends with User2
# User84 is friends with User2
# User72 is friends with User2
# User64 is friends with User2
# User63 is friends with User2
# User62 is friends with User2
# User60 is friends with User2
# User55 is friends with User2
# User53 is friends with User2
# User51 is friends with User2
# User46 is friends with User2
# User37 is friends with User2
# User35 is friends with User2
# User30 is friends with User2
# User24 is friends with User2
# User23 is friends with User2
# User17 is friends with User2
# User14 is friends with User2
# User12 is friends with User2
# User6 is friends with User2
# User1 is friends with User2
# User97 is friends with User3
# User96 is friends with User3
# User93 is friends with User3
# User83 is friends with User3
# User81 is friends with User3
# User77 is friends with User3
# User76 is friends with User3
# User75 is friends with User3
# User73 is friends with User3
# User72 is friends with User3
# User70 is friends with User3
# User68 is friends with User3
# User64 is friends with User3
# User62 is friends with User3
# User58 is friends with User3
# User53 is friends with User3
# User48 is friends with User3
# User46 is friends with User3
# User40 is friends with User3
# User38 is friends with User3
# User35 is friends with User3
# User34 is friends with User3
# User33 is friends with User3
# User30 is friends with User3
# User20 is friends with User3
# User18 is friends with User3
# User12 is friends with User3
# User9 is friends with User3
# User7 is friends with User3
# User5 is friends with User3
# User95 is friends with User4
# User83 is friends with User4
# User80 is friends with User4
# User76 is friends with User4
# User75 is friends with User4
# User73 is friends with User4
# User70 is friends with User4
# User62 is friends with User4
# User60 is friends with User4
# User56 is friends with User4
# User55 is friends with User4
# User45 is friends with User4
# User41 is friends with User4
# User35 is friends with User4
# User28 is friends with User4
# User25 is friends with User4
# User24 is friends with User4
# User23 is friends with User4
# User22 is friends with User4
# User17 is friends with User4
# User13 is friends with User4
# User11 is friends with User4
# User7 is friends with User4
# User98 is friends with User5
# User95 is friends with User5
# User93 is friends with User5
# User91 is friends with User5
# User86 is friends with User5
# User85 is friends with User5
# User83 is friends with User5
# User82 is friends with User5
# User76 is friends with User5
# User75 is friends with User5
# User73 is friends with User5
# User72 is friends with User5
# User65 is friends with User5
# User62 is friends with User5
# User56 is friends with User5
# User54 is friends with User5
# User50 is friends with User5
# User46 is friends with User5
# User40 is friends with User5
# User38 is friends with User5
# User34 is friends with User5
# User33 is friends with User5
# User30 is friends with User5
# User24 is friends with User5
# User23 is friends with User5
# User14 is friends with User5
# User11 is friends with User5
# User7 is friends with User5
# User6 is friends with User5
# User3 is friends with User5
# User95 is friends with User6
# User92 is friends with User6
# User89 is friends with User6
# User85 is friends with User6
# User83 is friends with User6
# User76 is friends with User6
# User75 is friends with User6
# User71 is friends with User6
# User70 is friends with User6
# User63 is friends with User6
# User53 is friends with User6
# User49 is friends with User6
# User47 is friends with User6
# User35 is friends with User6
# User34 is friends with User6
# User31 is friends with User6
# User30 is friends with User6
# User29 is friends with User6
# User24 is friends with User6
# User20 is friends with User6
# User17 is friends with User6
# User15 is friends with User6
# User13 is friends with User6
# User2 is friends with User6
# User5 is friends with User6
# User1 is friends with User6
# User91 is friends with User7
# User84 is friends with User7
# User83 is friends with User7
# User81 is friends with User7
# User76 is friends with User7
# User75 is friends with User7
# User72 is friends with User7
# User71 is friends with User7
# User64 is friends with User7
# User62 is friends with User7
# User56 is friends with User7
# User54 is friends with User7
# User53 is friends with User7
# User50 is friends with User7
# User49 is friends with User7
# User47 is friends with User7
# User46 is friends with User7
# User40 is friends with User7
# User37 is friends with User7
# User23 is friends with User7
# User17 is friends with User7
# User14 is friends with User7
# User10 is friends with User7
# User3 is friends with User7
# User5 is friends with User7
# User4 is friends with User7
# User100 is friends with User8
# User85 is friends with User8
# User84 is friends with User8
# User83 is friends with User8
# User80 is friends with User8
# User76 is friends with User8
# User73 is friends with User8
# User72 is friends with User8
# User68 is friends with User8
# User66 is friends with User8
# User65 is friends with User8
# User62 is friends with User8
# User47 is friends with User8
# User44 is friends with User8
# User39 is friends with User8
# User25 is friends with User8
# User20 is friends with User8
# User12 is friends with User8
# User97 is friends with User9
# User95 is friends with User9
# User94 is friends with User9
# User92 is friends with User9
# User87 is friends with User9
# User85 is friends with User9
# User83 is friends with User9
# User78 is friends with User9
# User76 is friends with User9
# User73 is friends with User9
# User72 is friends with User9
# User68 is friends with User9
# User65 is friends with User9
# User55 is friends with User9
# User50 is friends with User9
# User47 is friends with User9
# User44 is friends with User9
# User43 is friends with User9
# User40 is friends with User9
# User38 is friends with User9
# User34 is friends with User9
# User32 is friends with User9
# User27 is friends with User9
# User23 is friends with User9
# User20 is friends with User9
# User17 is friends with User9
# User14 is friends with User9
# User10 is friends with User9
# User3 is friends with User9
# User96 is friends with User10
# User94 is friends with User10
# User89 is friends with User10
# User77 is friends with User10
# User75 is friends with User10
# User73 is friends with User10
# User68 is friends with User10
# User56 is friends with User10
# User55 is friends with User10
# User49 is friends with User10
# User43 is friends with User10
# User42 is friends with User10
# User40 is friends with User10
# User38 is friends with User10
# User34 is friends with User10
# User28 is friends with User10
# User25 is friends with User10
# User20 is friends with User10
# User17 is friends with User10
# User14 is friends with User10
# User9 is friends with User10
# User7 is friends with User10
# User97 is friends with User11
# User94 is friends with User11
# User91 is friends with User11
# User89 is friends with User11
# User86 is friends with User11
# User85 is friends with User11
# User78 is friends with User11
# User76 is friends with User11
# User75 is friends with User11
# User73 is friends with User11
# User63 is friends with User11
# User62 is friends with User11
# User51 is friends with User11
# User49 is friends with User11
# User47 is friends with User11
# User41 is friends with User11
# User37 is friends with User11
# User33 is friends with User11
# User30 is friends with User11
# User29 is friends with User11
# User28 is friends with User11
# User23 is friends with User11
# User14 is friends with User11
# User13 is friends with User11
# User12 is friends with User11
# User4 is friends with User11
# User5 is friends with User11
# User100 is friends with User12
# User94 is friends with User12
# User86 is friends with User12
# User83 is friends with User12
# User82 is friends with User12
# User81 is friends with User12
# User75 is friends with User12
# User70 is friends with User12
# User56 is friends with User12
# User55 is friends with User12
# User53 is friends with User12
# User51 is friends with User12
# User50 is friends with User12
# User46 is friends with User12
# User44 is friends with User12
# User43 is friends with User12
# User42 is friends with User12
# User41 is friends with User12
# User38 is friends with User12
# User37 is friends with User12
# User34 is friends with User12
# User33 is friends with User12
# User31 is friends with User12
# User30 is friends with User12
# User29 is friends with User12
# User28 is friends with User12
# User24 is friends with User12
# User23 is friends with User12
# User18 is friends with User12
# User14 is friends with User12
# User8 is friends with User12
# User3 is friends with User12
# User1 is friends with User12
# User2 is friends with User12
# User11 is friends with User12
# User97 is friends with User13
# User93 is friends with User13
# User86 is friends with User13
# User76 is friends with User13
# User71 is friends with User13
# User70 is friends with User13
# User68 is friends with User13
# User63 is friends with User13
# User62 is friends with User13
# User55 is friends with User13
# User54 is friends with User13
# User53 is friends with User13
# User51 is friends with User13
# User50 is friends with User13
# User44 is friends with User13
# User43 is friends with User13
# User38 is friends with User13
# User33 is friends with User13
# User29 is friends with User13
# User28 is friends with User13
# User25 is friends with User13
# User17 is friends with User13
# User14 is friends with User13
# User1 is friends with User13
# User4 is friends with User13
# User6 is friends with User13
# User11 is friends with User13
# User98 is friends with User14
# User91 is friends with User14
# User83 is friends with User14
# User82 is friends with User14
# User80 is friends with User14
# User77 is friends with User14
# User75 is friends with User14
# User63 is friends with User14
# User62 is friends with User14
# User60 is friends with User14
# User55 is friends with User14
# User52 is friends with User14
# User51 is friends with User14
# User46 is friends with User14
# User43 is friends with User14
# User40 is friends with User14
# User33 is friends with User14
# User22 is friends with User14
# User18 is friends with User14
# User11 is friends with User14
# User7 is friends with User14
# User2 is friends with User14
# User5 is friends with User14
# User9 is friends with User14
# User12 is friends with User14
# User10 is friends with User14
# User13 is friends with User14
# User98 is friends with User15
# User97 is friends with User15
# User95 is friends with User15
# User94 is friends with User15
# User91 is friends with User15
# User89 is friends with User15
# User86 is friends with User15
# User85 is friends with User15
# User77 is friends with User15
# User70 is friends with User15
# User65 is friends with User15
# User64 is friends with User15
# User63 is friends with User15
# User62 is friends with User15
# User60 is friends with User15
# User55 is friends with User15
# User54 is friends with User15
# User44 is friends with User15
# User41 is friends with User15
# User37 is friends with User15
# User31 is friends with User15
# User30 is friends with User15
# User29 is friends with User15
# User23 is friends with User15
# User22 is friends with User15
# User20 is friends with User15
# User18 is friends with User15
# User6 is friends with User15
# User94 is friends with User16
# User92 is friends with User16
# User86 is friends with User16
# User84 is friends with User16
# User82 is friends with User16
# User81 is friends with User16
# User76 is friends with User16
# User74 is friends with User16
# User73 is friends with User16
# User71 is friends with User16
# User68 is friends with User16
# User66 is friends with User16
# User64 is friends with User16
# User63 is friends with User16
# User60 is friends with User16
# User59 is friends with User16
# User55 is friends with User16
# User54 is friends with User16
# User50 is friends with User16
# User49 is friends with User16
# User39 is friends with User16
# User30 is friends with User16
# User23 is friends with User16
# User20 is friends with User16
# User97 is friends with User17
# User80 is friends with User17
# User76 is friends with User17
# User72 is friends with User17
# User71 is friends with User17
# User70 is friends with User17
# User65 is friends with User17
# User60 is friends with User17
# User56 is friends with User17
# User52 is friends with User17
# User45 is friends with User17
# User37 is friends with User17
# User33 is friends with User17
# User32 is friends with User17
# User25 is friends with User17
# User7 is friends with User17
# User13 is friends with User17
# User9 is friends with User17
# User10 is friends with User17
# User6 is friends with User17
# User2 is friends with User17
# User4 is friends with User17
# User97 is friends with User18
# User95 is friends with User18
# User94 is friends with User18
# User92 is friends with User18
# User91 is friends with User18
# User86 is friends with User18
# User78 is friends with User18
# User73 is friends with User18
# User71 is friends with User18
# User68 is friends with User18
# User53 is friends with User18
# User49 is friends with User18
# User48 is friends with User18
# User47 is friends with User18
# User43 is friends with User18
# User39 is friends with User18
# User38 is friends with User18
# User34 is friends with User18
# User29 is friends with User18
# User27 is friends with User18
# User25 is friends with User18
# User24 is friends with User18
# User3 is friends with User18
# User14 is friends with User18
# User12 is friends with User18
# User15 is friends with User18
# User92 is friends with User19
# User85 is friends with User19
# User83 is friends with User19
# User82 is friends with User19
# User79 is friends with User19
# User75 is friends with User19
# User72 is friends with User19
# User71 is friends with User19
# User70 is friends with User19
# User62 is friends with User19
# User61 is friends with User19
# User54 is friends with User19
# User53 is friends with User19
# User50 is friends with User19
# User48 is friends with User19
# User37 is friends with User19
# User33 is friends with User19
# User31 is friends with User19
# User30 is friends with User19
# User25 is friends with User19
# User24 is friends with User19
# User23 is friends with User19
# User96 is friends with User20
# User91 is friends with User20
# User89 is friends with User20
# User86 is friends with User20
# User84 is friends with User20
# User83 is friends with User20
# User76 is friends with User20
# User75 is friends with User20
# User73 is friends with User20
# User70 is friends with User20
# User65 is friends with User20
# User58 is friends with User20
# User56 is friends with User20
# User55 is friends with User20
# User40 is friends with User20
# User35 is friends with User20
# User34 is friends with User20
# User33 is friends with User20
# User30 is friends with User20
# User23 is friends with User20
# User10 is friends with User20
# User9 is friends with User20
# User3 is friends with User20
# User6 is friends with User20
# User16 is friends with User20
# User8 is friends with User20
# User15 is friends with User20
# User97 is friends with User21
# User86 is friends with User21
# User83 is friends with User21
# User82 is friends with User21
# User80 is friends with User21
# User73 is friends with User21
# User72 is friends with User21
# User65 is friends with User21
# User62 is friends with User21
# User54 is friends with User21
# User47 is friends with User21
# User44 is friends with User21
# User40 is friends with User21
# User37 is friends with User21
# User25 is friends with User21
# User23 is friends with User21
# User100 is friends with User22
# User97 is friends with User22
# User85 is friends with User22
# User84 is friends with User22
# User83 is friends with User22
# User82 is friends with User22
# User78 is friends with User22
# User73 is friends with User22
# User72 is friends with User22
# User71 is friends with User22
# User55 is friends with User22
# User50 is friends with User22
# User47 is friends with User22
# User43 is friends with User22
# User42 is friends with User22
# User37 is friends with User22
# User29 is friends with User22
# User28 is friends with User22
# User25 is friends with User22
# User24 is friends with User22
# User4 is friends with User22
# User14 is friends with User22
# User15 is friends with User22
# User96 is friends with User23
# User95 is friends with User23
# User83 is friends with User23
# User82 is friends with User23
# User80 is friends with User23
# User78 is friends with User23
# User75 is friends with User23
# User73 is friends with User23
# User72 is friends with User23
# User65 is friends with User23
# User64 is friends with User23
# User63 is friends with User23
# User58 is friends with User23
# User51 is friends with User23
# User50 is friends with User23
# User48 is friends with User23
# User46 is friends with User23
# User44 is friends with User23
# User40 is friends with User23
# User39 is friends with User23
# User37 is friends with User23
# User34 is friends with User23
# User33 is friends with User23
# User31 is friends with User23
# User30 is friends with User23
# User29 is friends with User23
# User28 is friends with User23
# User25 is friends with User23
# User16 is friends with User23
# User9 is friends with User23
# User11 is friends with User23
# User19 is friends with User23
# User2 is friends with User23
# User20 is friends with User23
# User21 is friends with User23
# User7 is friends with User23
# User15 is friends with User23
# User5 is friends with User23
# User1 is friends with User23
# User12 is friends with User23
# User4 is friends with User23
# User97 is friends with User24
# User92 is friends with User24
# User81 is friends with User24
# User73 is friends with User24
# User72 is friends with User24
# User62 is friends with User24
# User44 is friends with User24
# User31 is friends with User24
# User29 is friends with User24
# User19 is friends with User24
# User6 is friends with User24
# User4 is friends with User24
# User12 is friends with User24
# User5 is friends with User24
# User22 is friends with User24
# User2 is friends with User24
# User18 is friends with User24
# User99 is friends with User25
# User94 is friends with User25
# User92 is friends with User25
# User86 is friends with User25
# User84 is friends with User25
# User83 is friends with User25
# User82 is friends with User25
# User79 is friends with User25
# User77 is friends with User25
# User73 is friends with User25
# User66 is friends with User25
# User63 is friends with User25
# User56 is friends with User25
# User55 is friends with User25
# User53 is friends with User25
# User40 is friends with User25
# User34 is friends with User25
# User29 is friends with User25
# User18 is friends with User25
# User4 is friends with User25
# User23 is friends with User25
# User17 is friends with User25
# User19 is friends with User25
# User21 is friends with User25
# User22 is friends with User25
# User13 is friends with User25
# User8 is friends with User25
# User10 is friends with User25
# User100 is friends with User26
# User99 is friends with User26
# User94 is friends with User26
# User89 is friends with User26
# User87 is friends with User26
# User77 is friends with User26
# User76 is friends with User26
# User72 is friends with User26
# User68 is friends with User26
# User63 is friends with User26
# User62 is friends with User26
# User51 is friends with User26
# User44 is friends with User26
# User42 is friends with User26
# User41 is friends with User26
# User40 is friends with User26
# User35 is friends with User26
# User31 is friends with User26
# User30 is friends with User26
# User94 is friends with User27
# User92 is friends with User27
# User91 is friends with User27
# User86 is friends with User27
# User85 is friends with User27
# User80 is friends with User27
# User73 is friends with User27
# User66 is friends with User27
# User64 is friends with User27
# User50 is friends with User27
# User47 is friends with User27
# User45 is friends with User27
# User44 is friends with User27
# User42 is friends with User27
# User40 is friends with User27
# User37 is friends with User27
# User29 is friends with User27
# User28 is friends with User27
# User18 is friends with User27
# User9 is friends with User27
# User100 is friends with User28
# User87 is friends with User28
# User83 is friends with User28
# User82 is friends with User28
# User76 is friends with User28
# User75 is friends with User28
# User74 is friends with User28
# User73 is friends with User28
# User72 is friends with User28
# User71 is friends with User28
# User69 is friends with User28
# User62 is friends with User28
# User56 is friends with User28
# User55 is friends with User28
# User50 is friends with User28
# User49 is friends with User28
# User44 is friends with User28
# User42 is friends with User28
# User38 is friends with User28
# User37 is friends with User28
# User29 is friends with User28
# User23 is friends with User28
# User27 is friends with User28
# User4 is friends with User28
# User22 is friends with User28
# User10 is friends with User28
# User13 is friends with User28
# User11 is friends with User28
# User12 is friends with User28
# User99 is friends with User29
# User95 is friends with User29
# User92 is friends with User29
# User89 is friends with User29
# User85 is friends with User29
# User84 is friends with User29
# User82 is friends with User29
# User78 is friends with User29
# User77 is friends with User29
# User76 is friends with User29
# User70 is friends with User29
# User68 is friends with User29
# User60 is friends with User29
# User55 is friends with User29
# User54 is friends with User29
# User43 is friends with User29
# User42 is friends with User29
# User38 is friends with User29
# User35 is friends with User29
# User34 is friends with User29
# User33 is friends with User29
# User30 is friends with User29
# User25 is friends with User29
# User18 is friends with User29
# User13 is friends with User29
# User11 is friends with User29
# User22 is friends with User29
# User6 is friends with User29
# User24 is friends with User29
# User12 is friends with User29
# User27 is friends with User29
# User28 is friends with User29
# User23 is friends with User29
# User15 is friends with User29
# User94 is friends with User30
# User92 is friends with User30
# User89 is friends with User30
# User86 is friends with User30
# User85 is friends with User30
# User83 is friends with User30
# User79 is friends with User30
# User75 is friends with User30
# User65 is friends with User30
# User64 is friends with User30
# User63 is friends with User30
# User62 is friends with User30
# User57 is friends with User30
# User56 is friends with User30
# User52 is friends with User30
# User44 is friends with User30
# User20 is friends with User30
# User29 is friends with User30
# User1 is friends with User30
# User23 is friends with User30
# User5 is friends with User30
# User16 is friends with User30
# User26 is friends with User30
# User6 is friends with User30
# User12 is friends with User30
# User2 is friends with User30
# User11 is friends with User30
# User19 is friends with User30
# User15 is friends with User30
# User3 is friends with User30
# User97 is friends with User31
# User86 is friends with User31
# User81 is friends with User31
# User80 is friends with User31
# User77 is friends with User31
# User76 is friends with User31
# User75 is friends with User31
# User72 is friends with User31
# User70 is friends with User31
# User68 is friends with User31
# User65 is friends with User31
# User63 is friends with User31
# User62 is friends with User31
# User58 is friends with User31
# User54 is friends with User31
# User49 is friends with User31
# User41 is friends with User31
# User6 is friends with User31
# User23 is friends with User31
# User15 is friends with User31
# User24 is friends with User31
# User26 is friends with User31
# User1 is friends with User31
# User19 is friends with User31
# User12 is friends with User31
# User97 is friends with User32
# User94 is friends with User32
# User85 is friends with User32
# User84 is friends with User32
# User78 is friends with User32
# User77 is friends with User32
# User71 is friends with User32
# User65 is friends with User32
# User63 is friends with User32
# User57 is friends with User32
# User44 is friends with User32
# User43 is friends with User32
# User38 is friends with User32
# User9 is friends with User32
# User17 is friends with User32
# User97 is friends with User33
# User95 is friends with User33
# User94 is friends with User33
# User91 is friends with User33
# User90 is friends with User33
# User86 is friends with User33
# User82 is friends with User33
# User79 is friends with User33
# User76 is friends with User33
# User73 is friends with User33
# User71 is friends with User33
# User70 is friends with User33
# User68 is friends with User33
# User50 is friends with User33
# User38 is friends with User33
# User37 is friends with User33
# User13 is friends with User33
# User12 is friends with User33
# User23 is friends with User33
# User19 is friends with User33
# User17 is friends with User33
# User29 is friends with User33
# User20 is friends with User33
# User5 is friends with User33
# User11 is friends with User33
# User3 is friends with User33
# User14 is friends with User33
# User96 is friends with User34
# User94 is friends with User34
# User81 is friends with User34
# User74 is friends with User34
# User72 is friends with User34
# User64 is friends with User34
# User62 is friends with User34
# User61 is friends with User34
# User58 is friends with User34
# User52 is friends with User34
# User49 is friends with User34
# User46 is friends with User34
# User43 is friends with User34
# User41 is friends with User34
# User37 is friends with User34
# User20 is friends with User34
# User10 is friends with User34
# User12 is friends with User34
# User23 is friends with User34
# User18 is friends with User34
# User25 is friends with User34
# User29 is friends with User34
# User9 is friends with User34
# User6 is friends with User34
# User3 is friends with User34
# User5 is friends with User34
# User100 is friends with User35
# User99 is friends with User35
# User98 is friends with User35
# User94 is friends with User35
# User93 is friends with User35
# User92 is friends with User35
# User91 is friends with User35
# User89 is friends with User35
# User84 is friends with User35
# User82 is friends with User35
# User80 is friends with User35
# User79 is friends with User35
# User78 is friends with User35
# User73 is friends with User35
# User72 is friends with User35
# User68 is friends with User35
# User64 is friends with User35
# User61 is friends with User35
# User60 is friends with User35
# User58 is friends with User35
# User52 is friends with User35
# User50 is friends with User35
# User48 is friends with User35
# User46 is friends with User35
# User44 is friends with User35
# User41 is friends with User35
# User37 is friends with User35
# User6 is friends with User35
# User4 is friends with User35
# User2 is friends with User35
# User3 is friends with User35
# User20 is friends with User35
# User26 is friends with User35
# User29 is friends with User35
# User99 is friends with User36
# User92 is friends with User36
# User89 is friends with User36
# User85 is friends with User36
# User84 is friends with User36
# User83 is friends with User36
# User81 is friends with User36
# User73 is friends with User36
# User72 is friends with User36
# User68 is friends with User36
# User65 is friends with User36
# User62 is friends with User36
# User60 is friends with User36
# User56 is friends with User36
# User53 is friends with User36
# User51 is friends with User36
# User47 is friends with User36
# User40 is friends with User36
# User96 is friends with User37
# User94 is friends with User37
# User90 is friends with User37
# User86 is friends with User37
# User78 is friends with User37
# User76 is friends with User37
# User70 is friends with User37
# User65 is friends with User37
# User58 is friends with User37
# User56 is friends with User37
# User44 is friends with User37
# User42 is friends with User37
# User15 is friends with User37
# User35 is friends with User37
# User22 is friends with User37
# User11 is friends with User37
# User23 is friends with User37
# User33 is friends with User37
# User19 is friends with User37
# User21 is friends with User37
# User17 is friends with User37
# User2 is friends with User37
# User27 is friends with User37
# User7 is friends with User37
# User34 is friends with User37
# User1 is friends with User37
# User28 is friends with User37
# User12 is friends with User37
# User95 is friends with User38
# User85 is friends with User38
# User79 is friends with User38
# User78 is friends with User38
# User77 is friends with User38
# User75 is friends with User38
# User73 is friends with User38
# User72 is friends with User38
# User71 is friends with User38
# User68 is friends with User38
# User60 is friends with User38
# User58 is friends with User38
# User53 is friends with User38
# User47 is friends with User38
# User44 is friends with User38
# User40 is friends with User38
# User9 is friends with User38
# User13 is friends with User38
# User29 is friends with User38
# User33 is friends with User38
# User32 is friends with User38
# User3 is friends with User38
# User10 is friends with User38
# User18 is friends with User38
# User5 is friends with User38
# User28 is friends with User38
# User12 is friends with User38
# User1 is friends with User38
# User100 is friends with User39
# User94 is friends with User39
# User91 is friends with User39
# User86 is friends with User39
# User85 is friends with User39
# User84 is friends with User39
# User83 is friends with User39
# User78 is friends with User39
# User77 is friends with User39
# User73 is friends with User39
# User68 is friends with User39
# User63 is friends with User39
# User53 is friends with User39
# User52 is friends with User39
# User51 is friends with User39
# User50 is friends with User39
# User47 is friends with User39
# User44 is friends with User39
# User41 is friends with User39
# User23 is friends with User39
# User8 is friends with User39
# User16 is friends with User39
# User18 is friends with User39
# User100 is friends with User40
# User95 is friends with User40
# User93 is friends with User40
# User89 is friends with User40
# User85 is friends with User40
# User84 is friends with User40
# User78 is friends with User40
# User77 is friends with User40
# User75 is friends with User40
# User73 is friends with User40
# User71 is friends with User40
# User64 is friends with User40
# User58 is friends with User40
# User53 is friends with User40
# User52 is friends with User40
# User50 is friends with User40
# User48 is friends with User40
# User47 is friends with User40
# User43 is friends with User40
# User42 is friends with User40
# User27 is friends with User40
# User38 is friends with User40
# User21 is friends with User40
# User7 is friends with User40
# User23 is friends with User40
# User26 is friends with User40
# User20 is friends with User40
# User25 is friends with User40
# User5 is friends with User40
# User9 is friends with User40
# User36 is friends with User40
# User3 is friends with User40
# User10 is friends with User40
# User14 is friends with User40
# User93 is friends with User41
# User81 is friends with User41
# User80 is friends with User41
# User78 is friends with User41
# User75 is friends with User41
# User71 is friends with User41
# User64 is friends with User41
# User63 is friends with User41
# User61 is friends with User41
# User60 is friends with User41
# User53 is friends with User41
# User52 is friends with User41
# User51 is friends with User41
# User50 is friends with User41
# User31 is friends with User41
# User26 is friends with User41
# User4 is friends with User41
# User12 is friends with User41
# User34 is friends with User41
# User1 is friends with User41
# User35 is friends with User41
# User39 is friends with User41
# User11 is friends with User41
# User15 is friends with User41
# User100 is friends with User42
# User95 is friends with User42
# User94 is friends with User42
# User91 is friends with User42
# User85 is friends with User42
# User75 is friends with User42
# User73 is friends with User42
# User71 is friends with User42
# User65 is friends with User42
# User57 is friends with User42
# User56 is friends with User42
# User52 is friends with User42
# User50 is friends with User42
# User44 is friends with User42
# User27 is friends with User42
# User37 is friends with User42
# User29 is friends with User42
# User22 is friends with User42
# User40 is friends with User42
# User26 is friends with User42
# User10 is friends with User42
# User28 is friends with User42
# User12 is friends with User42
# User99 is friends with User43
# User95 is friends with User43
# User89 is friends with User43
# User81 is friends with User43
# User77 is friends with User43
# User73 is friends with User43
# User72 is friends with User43
# User71 is friends with User43
# User70 is friends with User43
# User65 is friends with User43
# User62 is friends with User43
# User53 is friends with User43
# User51 is friends with User43
# User50 is friends with User43
# User47 is friends with User43
# User46 is friends with User43
# User18 is friends with User43
# User40 is friends with User43
# User32 is friends with User43
# User9 is friends with User43
# User22 is friends with User43
# User29 is friends with User43
# User34 is friends with User43
# User10 is friends with User43
# User12 is friends with User43
# User14 is friends with User43
# User13 is friends with User43
# User97 is friends with User44
# User96 is friends with User44
# User95 is friends with User44
# User91 is friends with User44
# User87 is friends with User44
# User84 is friends with User44
# User80 is friends with User44
# User75 is friends with User44
# User70 is friends with User44
# User68 is friends with User44
# User65 is friends with User44
# User61 is friends with User44
# User56 is friends with User44
# User55 is friends with User44
# User35 is friends with User44
# User8 is friends with User44
# User23 is friends with User44
# User27 is friends with User44
# User32 is friends with User44
# User30 is friends with User44
# User26 is friends with User44
# User42 is friends with User44
# User38 is friends with User44
# User9 is friends with User44
# User12 is friends with User44
# User39 is friends with User44
# User21 is friends with User44
# User1 is friends with User44
# User15 is friends with User44
# User28 is friends with User44
# User13 is friends with User44
# User24 is friends with User44
# User37 is friends with User44
# User97 is friends with User45
# User92 is friends with User45
# User91 is friends with User45
# User89 is friends with User45
# User82 is friends with User45
# User80 is friends with User45
# User71 is friends with User45
# User70 is friends with User45
# User68 is friends with User45
# User64 is friends with User45
# User58 is friends with User45
# User56 is friends with User45
# User53 is friends with User45
# User50 is friends with User45
# User27 is friends with User45
# User17 is friends with User45
# User4 is friends with User45
# User96 is friends with User46
# User95 is friends with User46
# User94 is friends with User46
# User91 is friends with User46
# User82 is friends with User46
# User78 is friends with User46
# User75 is friends with User46
# User70 is friends with User46
# User66 is friends with User46
# User64 is friends with User46
# User58 is friends with User46
# User53 is friends with User46
# User47 is friends with User46
# User34 is friends with User46
# User35 is friends with User46
# User3 is friends with User46
# User23 is friends with User46
# User14 is friends with User46
# User12 is friends with User46
# User2 is friends with User46
# User43 is friends with User46
# User7 is friends with User46
# User5 is friends with User46
# User95 is friends with User47
# User94 is friends with User47
# User91 is friends with User47
# User89 is friends with User47
# User82 is friends with User47
# User74 is friends with User47
# User73 is friends with User47
# User65 is friends with User47
# User64 is friends with User47
# User63 is friends with User47
# User62 is friends with User47
# User56 is friends with User47
# User52 is friends with User47
# User50 is friends with User47
# User11 is friends with User47
# User39 is friends with User47
# User9 is friends with User47
# User27 is friends with User47
# User8 is friends with User47
# User46 is friends with User47
# User22 is friends with User47
# User21 is friends with User47
# User7 is friends with User47
# User6 is friends with User47
# User40 is friends with User47
# User36 is friends with User47
# User38 is friends with User47
# User43 is friends with User47
# User18 is friends with User47
# User100 is friends with User48
# User97 is friends with User48
# User94 is friends with User48
# User92 is friends with User48
# User86 is friends with User48
# User78 is friends with User48
# User77 is friends with User48
# User72 is friends with User48
# User70 is friends with User48
# User69 is friends with User48
# User64 is friends with User48
# User62 is friends with User48
# User60 is friends with User48
# User18 is friends with User48
# User40 is friends with User48
# User23 is friends with User48
# User3 is friends with User48
# User35 is friends with User48
# User19 is friends with User48
# User95 is friends with User49
# User94 is friends with User49
# User93 is friends with User49
# User85 is friends with User49
# User84 is friends with User49
# User77 is friends with User49
# User75 is friends with User49
# User74 is friends with User49
# User73 is friends with User49
# User70 is friends with User49
# User68 is friends with User49
# User64 is friends with User49
# User63 is friends with User49
# User62 is friends with User49
# User56 is friends with User49
# User51 is friends with User49
# User50 is friends with User49
# User11 is friends with User49
# User34 is friends with User49
# User16 is friends with User49
# User18 is friends with User49
# User7 is friends with User49
# User6 is friends with User49
# User10 is friends with User49
# User28 is friends with User49
# User1 is friends with User49
# User31 is friends with User49
# User96 is friends with User50
# User94 is friends with User50
# User91 is friends with User50
# User90 is friends with User50
# User89 is friends with User50
# User84 is friends with User50
# User76 is friends with User50
# User64 is friends with User50
# User62 is friends with User50
# User60 is friends with User50
# User35 is friends with User50
# User16 is friends with User50
# User7 is friends with User50
# User28 is friends with User50
# User19 is friends with User50
# User27 is friends with User50
# User40 is friends with User50
# User42 is friends with User50
# User45 is friends with User50
# User22 is friends with User50
# User9 is friends with User50
# User12 is friends with User50
# User33 is friends with User50
# User47 is friends with User50
# User49 is friends with User50
# User41 is friends with User50
# User39 is friends with User50
# User13 is friends with User50
# User43 is friends with User50
# User23 is friends with User50
# User5 is friends with User50
# User95 is friends with User51
# User94 is friends with User51
# User89 is friends with User51
# User82 is friends with User51
# User72 is friends with User51
# User62 is friends with User51
# User11 is friends with User51
# User41 is friends with User51
# User23 is friends with User51
# User2 is friends with User51
# User49 is friends with User51
# User12 is friends with User51
# User36 is friends with User51
# User39 is friends with User51
# User26 is friends with User51
# User13 is friends with User51
# User14 is friends with User51
# User43 is friends with User51
# User94 is friends with User52
# User89 is friends with User52
# User86 is friends with User52
# User78 is friends with User52
# User77 is friends with User52
# User75 is friends with User52
# User72 is friends with User52
# User70 is friends with User52
# User64 is friends with User52
# User60 is friends with User52
# User56 is friends with User52
# User53 is friends with User52
# User40 is friends with User52
# User1 is friends with User52
# User35 is friends with User52
# User30 is friends with User52
# User41 is friends with User52
# User47 is friends with User52
# User34 is friends with User52
# User39 is friends with User52
# User14 is friends with User52
# User42 is friends with User52
# User17 is friends with User52
# User96 is friends with User53
# User90 is friends with User53
# User86 is friends with User53
# User83 is friends with User53
# User75 is friends with User53
# User71 is friends with User53
# User68 is friends with User53
# User65 is friends with User53
# User62 is friends with User53
# User56 is friends with User53
# User55 is friends with User53
# User46 is friends with User53
# User6 is friends with User53
# User18 is friends with User53
# User45 is friends with User53
# User19 is friends with User53
# User36 is friends with User53
# User43 is friends with User53
# User13 is friends with User53
# User2 is friends with User53
# User25 is friends with User53
# User38 is friends with User53
# User12 is friends with User53
# User40 is friends with User53
# User52 is friends with User53
# User7 is friends with User53
# User3 is friends with User53
# User39 is friends with User53
# User41 is friends with User53
# User95 is friends with User54
# User91 is friends with User54
# User86 is friends with User54
# User85 is friends with User54
# User70 is friends with User54
# User64 is friends with User54
# User62 is friends with User54
# User60 is friends with User54
# User56 is friends with User54
# User5 is friends with User54
# User29 is friends with User54
# User19 is friends with User54
# User16 is friends with User54
# User7 is friends with User54
# User13 is friends with User54
# User21 is friends with User54
# User15 is friends with User54
# User31 is friends with User54
# User100 is friends with User55
# User93 is friends with User55
# User92 is friends with User55
# User91 is friends with User55
# User85 is friends with User55
# User77 is friends with User55
# User76 is friends with User55
# User75 is friends with User55
# User74 is friends with User55
# User73 is friends with User55
# User72 is friends with User55
# User68 is friends with User55
# User65 is friends with User55
# User62 is friends with User55
# User61 is friends with User55
# User58 is friends with User55
# User56 is friends with User55
# User22 is friends with User55
# User20 is friends with User55
# User15 is friends with User55
# User9 is friends with User55
# User25 is friends with User55
# User44 is friends with User55
# User1 is friends with User55
# User14 is friends with User55
# User16 is friends with User55
# User53 is friends with User55
# User10 is friends with User55
# User2 is friends with User55
# User29 is friends with User55
# User12 is friends with User55
# User4 is friends with User55
# User28 is friends with User55
# User13 is friends with User55
# User95 is friends with User56
# User91 is friends with User56
# User86 is friends with User56
# User82 is friends with User56
# User78 is friends with User56
# User73 is friends with User56
# User71 is friends with User56
# User70 is friends with User56
# User65 is friends with User56
# User20 is friends with User56
# User55 is friends with User56
# User10 is friends with User56
# User54 is friends with User56
# User4 is friends with User56
# User17 is friends with User56
# User12 is friends with User56
# User53 is friends with User56
# User7 is friends with User56
# User25 is friends with User56
# User37 is friends with User56
# User47 is friends with User56
# User45 is friends with User56
# User44 is friends with User56
# User28 is friends with User56
# User42 is friends with User56
# User30 is friends with User56
# User52 is friends with User56
# User36 is friends with User56
# User5 is friends with User56
# User49 is friends with User56
# User95 is friends with User57
# User94 is friends with User57
# User92 is friends with User57
# User84 is friends with User57
# User80 is friends with User57
# User78 is friends with User57
# User73 is friends with User57
# User70 is friends with User57
# User65 is friends with User57
# User42 is friends with User57
# User30 is friends with User57
# User32 is friends with User57
# User99 is friends with User58
# User95 is friends with User58
# User93 is friends with User58
# User92 is friends with User58
# User91 is friends with User58
# User86 is friends with User58
# User77 is friends with User58
# User75 is friends with User58
# User74 is friends with User58
# User73 is friends with User58
# User65 is friends with User58
# User59 is friends with User58
# User38 is friends with User58
# User3 is friends with User58
# User20 is friends with User58
# User45 is friends with User58
# User40 is friends with User58
# User34 is friends with User58
# User35 is friends with User58
# User23 is friends with User58
# User46 is friends with User58
# User31 is friends with User58
# User37 is friends with User58
# User55 is friends with User58
# User97 is friends with User59
# User95 is friends with User59
# User93 is friends with User59
# User87 is friends with User59
# User85 is friends with User59
# User82 is friends with User59
# User81 is friends with User59
# User80 is friends with User59
# User77 is friends with User59
# User76 is friends with User59
# User75 is friends with User59
# User73 is friends with User59
# User72 is friends with User59
# User63 is friends with User59
# User61 is friends with User59
# User16 is friends with User59
# User58 is friends with User59
# User97 is friends with User60
# User94 is friends with User60
# User92 is friends with User60
# User89 is friends with User60
# User79 is friends with User60
# User75 is friends with User60
# User73 is friends with User60
# User70 is friends with User60
# User16 is friends with User60
# User52 is friends with User60
# User50 is friends with User60
# User2 is friends with User60
# User4 is friends with User60
# User17 is friends with User60
# User48 is friends with User60
# User35 is friends with User60
# User36 is friends with User60
# User54 is friends with User60
# User29 is friends with User60
# User15 is friends with User60
# User41 is friends with User60
# User38 is friends with User60
# User14 is friends with User60
# User97 is friends with User61
# User95 is friends with User61
# User94 is friends with User61
# User82 is friends with User61
# User80 is friends with User61
# User77 is friends with User61
# User75 is friends with User61
# User70 is friends with User61
# User35 is friends with User61
# User44 is friends with User61
# User34 is friends with User61
# User41 is friends with User61
# User55 is friends with User61
# User59 is friends with User61
# User19 is friends with User61
# User96 is friends with User62
# User89 is friends with User62
# User82 is friends with User62
# User81 is friends with User62
# User80 is friends with User62
# User75 is friends with User62
# User72 is friends with User62
# User70 is friends with User62
# User68 is friends with User62
# User65 is friends with User62
# User63 is friends with User62
# User14 is friends with User62
# User2 is friends with User62
# User54 is friends with User62
# User51 is friends with User62
# User13 is friends with User62
# User30 is friends with User62
# User47 is friends with User62
# User15 is friends with User62
# User7 is friends with User62
# User28 is friends with User62
# User24 is friends with User62
# User43 is friends with User62
# User50 is friends with User62
# User48 is friends with User62
# User31 is friends with User62
# User11 is friends with User62
# User55 is friends with User62
# User34 is friends with User62
# User36 is friends with User62
# User21 is friends with User62
# User49 is friends with User62
# User8 is friends with User62
# User19 is friends with User62
# User53 is friends with User62
# User3 is friends with User62
# User4 is friends with User62
# User26 is friends with User62
# User5 is friends with User62
# User96 is friends with User63
# User95 is friends with User63
# User94 is friends with User63
# User93 is friends with User63
# User92 is friends with User63
# User89 is friends with User63
# User86 is friends with User63
# User82 is friends with User63
# User80 is friends with User63
# User72 is friends with User63
# User71 is friends with User63
# User68 is friends with User63
# User64 is friends with User63
# User31 is friends with User63
# User49 is friends with User63
# User30 is friends with User63
# User47 is friends with User63
# User1 is friends with User63
# User11 is friends with User63
# User15 is friends with User63
# User59 is friends with User63
# User62 is friends with User63
# User32 is friends with User63
# User41 is friends with User63
# User14 is friends with User63
# User39 is friends with User63
# User2 is friends with User63
# User25 is friends with User63
# User26 is friends with User63
# User23 is friends with User63
# User13 is friends with User63
# User16 is friends with User63
# User6 is friends with User63
# User96 is friends with User64
# User91 is friends with User64
# User88 is friends with User64
# User78 is friends with User64
# User75 is friends with User64
# User70 is friends with User64
# User69 is friends with User64
# User68 is friends with User64
# User65 is friends with User64
# ...
# User8 is friends with User80
# User59 is friends with User80
# User63 is friends with User80
# User27 is friends with User80
# User35 is friends with User80
# User61 is friends with User80
# User23 is friends with User80
# User45 is friends with User80
# User14 is friends with User80
# User21 is friends with User80
# User65 is friends with User80
# User92 is friends with User81
# User91 is friends with User81
# User86 is friends with User81
# User84 is friends with User81
# User83 is friends with User81
# User34 is friends with User81
# User36 is friends with User81
# User3 is friends with User81
# User31 is friends with User81
# User72 is friends with User81
# User59 is friends with User81
# User43 is friends with User81
# User12 is friends with User81
# User24 is friends with User81
# User41 is friends with User81
# User62 is friends with User81
# User7 is friends with User81
# User78 is friends with User81
# User16 is friends with User81
# User71 is friends with User81
# User95 is friends with User82
# User94 is friends with User82
# User89 is friends with User82
# User85 is friends with User82
# User21 is friends with User82
# User35 is friends with User82
# User29 is friends with User82
# User71 is friends with User82
# User59 is friends with User82
# User33 is friends with User82
# User22 is friends with User82
# User14 is friends with User82
# User79 is friends with User82
# User28 is friends with User82
# User63 is friends with User82
# User72 is friends with User82
# User80 is friends with User82
# User45 is friends with User82
# User5 is friends with User82
# User69 is friends with User82
# User62 is friends with User82
# User16 is friends with User82
# User56 is friends with User82
# User23 is friends with User82
# User65 is friends with User82
# User1 is friends with User82
# User12 is friends with User82
# User75 is friends with User82
# User25 is friends with User82
# User46 is friends with User82
# User51 is friends with User82
# User19 is friends with User82
# User47 is friends with User82
# User61 is friends with User82
# User77 is friends with User82
# User95 is friends with User83
# User94 is friends with User83
# User92 is friends with User83
# User19 is friends with User83
# User3 is friends with User83
# User23 is friends with User83
# User75 is friends with User83
# User25 is friends with User83
# User22 is friends with User83
# User28 is friends with User83
# User71 is friends with User83
# User69 is friends with User83
# User76 is friends with User83
# User30 is friends with User83
# User78 is friends with User83
# User53 is friends with User83
# User79 is friends with User83
# User7 is friends with User83
# User36 is friends with User83
# User20 is friends with User83
# User14 is friends with User83
# User4 is friends with User83
# User21 is friends with User83
# User12 is friends with User83
# User9 is friends with User83
# User68 is friends with User83
# User39 is friends with User83
# User81 is friends with User83
# User8 is friends with User83
# User6 is friends with User83
# User70 is friends with User83
# User5 is friends with User83
# User96 is friends with User84
# User95 is friends with User84
# User94 is friends with User84
# User93 is friends with User84
# User92 is friends with User84
# User91 is friends with User84
# User90 is friends with User84
# User89 is friends with User84
# User85 is friends with User84
# User66 is friends with User84
# User76 is friends with User84
# User8 is friends with User84
# User68 is friends with User84
# User69 is friends with User84
# User22 is friends with User84
# User75 is friends with User84
# User40 is friends with User84
# User73 is friends with User84
# User78 is friends with User84
# User29 is friends with User84
# User35 is friends with User84
# User7 is friends with User84
# User25 is friends with User84
# User57 is friends with User84
# User50 is friends with User84
# User49 is friends with User84
# User2 is friends with User84
# User36 is friends with User84
# User32 is friends with User84
# User20 is friends with User84
# User39 is friends with User84
# User44 is friends with User84
# User16 is friends with User84
# User81 is friends with User84
# User98 is friends with User85
# User95 is friends with User85
# User91 is friends with User85
# User86 is friends with User85
# User36 is friends with User85
# User42 is friends with User85
# User54 is friends with User85
# User11 is friends with User85
# User8 is friends with User85
# User55 is friends with User85
# User15 is friends with User85
# User71 is friends with User85
# User68 is friends with User85
# User65 is friends with User85
# User9 is friends with User85
# User59 is friends with User85
# User6 is friends with User85
# User84 is friends with User85
# User39 is friends with User85
# User82 is friends with User85
# User29 is friends with User85
# User19 is friends with User85
# User32 is friends with User85
# User49 is friends with User85
# User2 is friends with User85
# User5 is friends with User85
# User30 is friends with User85
# User22 is friends with User85
# User1 is friends with User85
# User38 is friends with User85
# User40 is friends with User85
# User27 is friends with User85
# User74 is friends with User85
# User96 is friends with User86
# User94 is friends with User86
# User93 is friends with User86
# User92 is friends with User86
# User91 is friends with User86
# User56 is friends with User86
# User15 is friends with User86
# User58 is friends with User86
# User12 is friends with User86
# User48 is friends with User86
# User5 is friends with User86
# User81 is friends with User86
# User21 is friends with User86
# User18 is friends with User86
# User39 is friends with User86
# User20 is friends with User86
# User67 is friends with User86
# User33 is friends with User86
# User25 is friends with User86
# User31 is friends with User86
# User73 is friends with User86
# User30 is friends with User86
# User72 is friends with User86
# User52 is friends with User86
# User76 is friends with User86
# User54 is friends with User86
# User37 is friends with User86
# User53 is friends with User86
# User16 is friends with User86
# User2 is friends with User86
# User77 is friends with User86
# User85 is friends with User86
# User63 is friends with User86
# User75 is friends with User86
# User66 is friends with User86
# User11 is friends with User86
# User27 is friends with User86
# User13 is friends with User86
# User93 is friends with User87
# User92 is friends with User87
# User91 is friends with User87
# User90 is friends with User87
# User44 is friends with User87
# User28 is friends with User87
# User67 is friends with User87
# User59 is friends with User87
# User9 is friends with User87
# User75 is friends with User87
# User26 is friends with User87
# User73 is friends with User87
# User95 is friends with User88
# User94 is friends with User88
# User92 is friends with User88
# User64 is friends with User88
# User97 is friends with User89
# User95 is friends with User89
# User94 is friends with User89
# User91 is friends with User89
# User90 is friends with User89
# User6 is friends with User89
# User66 is friends with User89
# User82 is friends with User89
# User62 is friends with User89
# User40 is friends with User89
# User84 is friends with User89
# User10 is friends with User89
# User45 is friends with User89
# User52 is friends with User89
# User36 is friends with User89
# User78 is friends with User89
# User51 is friends with User89
# User69 is friends with User89
# User63 is friends with User89
# User15 is friends with User89
# User60 is friends with User89
# User29 is friends with User89
# User43 is friends with User89
# User30 is friends with User89
# User77 is friends with User89
# User11 is friends with User89
# User50 is friends with User89
# User79 is friends with User89
# User76 is friends with User89
# User20 is friends with User89
# User2 is friends with User89
# User26 is friends with User89
# User35 is friends with User89
# User47 is friends with User89
# User100 is friends with User90
# User95 is friends with User90
# User53 is friends with User90
# User84 is friends with User90
# User50 is friends with User90
# User89 is friends with User90
# User87 is friends with User90
# User37 is friends with User90
# User33 is friends with User90
# User78 is friends with User90
# User2 is friends with User90
# User100 is friends with User91
# User96 is friends with User91
# User45 is friends with User91
# User18 is friends with User91
# User50 is friends with User91
# User11 is friends with User91
# User58 is friends with User91
# User14 is friends with User91
# User46 is friends with User91
# User44 is friends with User91
# User70 is friends with User91
# User65 is friends with User91
# User87 is friends with User91
# User85 is friends with User91
# User35 is friends with User91
# User81 is friends with User91
# User47 is friends with User91
# User54 is friends with User91
# User84 is friends with User91
# User73 is friends with User91
# User89 is friends with User91
# User20 is friends with User91
# User5 is friends with User91
# User39 is friends with User91
# User64 is friends with User91
# User15 is friends with User91
# User76 is friends with User91
# User27 is friends with User91
# User56 is friends with User91
# User33 is friends with User91
# User42 is friends with User91
# User7 is friends with User91
# User80 is friends with User91
# User74 is friends with User91
# User55 is friends with User91
# User86 is friends with User91
# User100 is friends with User92
# User97 is friends with User92
# User6 is friends with User92
# User19 is friends with User92
# User35 is friends with User92
# User88 is friends with User92
# User36 is friends with User92
# User25 is friends with User92
# User86 is friends with User92
# User24 is friends with User92
# User48 is friends with User92
# User45 is friends with User92
# User18 is friends with User92
# User66 is friends with User92
# User84 is friends with User92
# User57 is friends with User92
# User68 is friends with User92
# User1 is friends with User92
# User72 is friends with User92
# User29 is friends with User92
# User60 is friends with User92
# User81 is friends with User92
# User69 is friends with User92
# User55 is friends with User92
# User30 is friends with User92
# User27 is friends with User92
# User87 is friends with User92
# User9 is friends with User92
# User58 is friends with User92
# User16 is friends with User92
# User83 is friends with User92
# User63 is friends with User92
# User98 is friends with User93
# User95 is friends with User93
# User94 is friends with User93
# User13 is friends with User93
# User86 is friends with User93
# User41 is friends with User93
# User67 is friends with User93
# User49 is friends with User93
# User74 is friends with User93
# User68 is friends with User93
# User58 is friends with User93
# User40 is friends with User93
# User84 is friends with User93
# User3 is friends with User93
# User55 is friends with User93
# User87 is friends with User93
# User59 is friends with User93
# User63 is friends with User93
# User35 is friends with User93
# User5 is friends with User93
# User100 is friends with User94
# User95 is friends with User94
# User47 is friends with User94
# User89 is friends with User94
# User51 is friends with User94
# User60 is friends with User94
# User69 is friends with User94
# User11 is friends with User94
# User88 is friends with User94
# User16 is friends with User94
# User12 is friends with User94
# User93 is friends with User94
# User10 is friends with User94
# User30 is friends with User94
# User48 is friends with User94
# User33 is friends with User94
# User18 is friends with User94
# User49 is friends with User94
# User50 is friends with User94
# User66 is friends with User94
# User77 is friends with User94
# User65 is friends with User94
# User57 is friends with User94
# User79 is friends with User94
# User27 is friends with User94
# User42 is friends with User94
# User39 is friends with User94
# User61 is friends with User94
# User63 is friends with User94
# User86 is friends with User94
# User1 is friends with User94
# User25 is friends with User94
# User73 is friends with User94
# User32 is friends with User94
# User34 is friends with User94
# User82 is friends with User94
# User46 is friends with User94
# User37 is friends with User94
# User35 is friends with User94
# User9 is friends with User94
# User52 is friends with User94
# User78 is friends with User94
# User83 is friends with User94
# User84 is friends with User94
# User15 is friends with User94
# User75 is friends with User94
# User26 is friends with User94
# User82 is friends with User95
# User5 is friends with User95
# User83 is friends with User95
# User29 is friends with User95
# User47 is friends with User95
# User84 is friends with User95
# User42 is friends with User95
# User1 is friends with User95
# User40 is friends with User95
# User43 is friends with User95
# User4 is friends with User95
# User65 is friends with User95
# User93 is friends with User95
# User73 is friends with User95
# User6 is friends with User95
# User2 is friends with User95
# User61 is friends with User95
# User56 is friends with User95
# User80 is friends with User95
# User85 is friends with User95
# User33 is friends with User95
# User58 is friends with User95
# User18 is friends with User95
# User38 is friends with User95
# User71 is friends with User95
# User44 is friends with User95
# User9 is friends with User95
# User77 is friends with User95
# User90 is friends with User95
# User23 is friends with User95
# User63 is friends with User95
# User49 is friends with User95
# User59 is friends with User95
# User57 is friends with User95
# User89 is friends with User95
# User46 is friends with User95
# User94 is friends with User95
# User88 is friends with User95
# User54 is friends with User95
# User51 is friends with User95
# User15 is friends with User95
# User99 is friends with User96
# User71 is friends with User96
# User53 is friends with User96
# User44 is friends with User96
# User3 is friends with User96
# User91 is friends with User96
# User76 is friends with User96
# User80 is friends with User96
# User50 is friends with User96
# User69 is friends with User96
# User66 is friends with User96
# User23 is friends with User96
# User10 is friends with User96
# User70 is friends with User96
# User64 is friends with User96
# User62 is friends with User96
# User37 is friends with User96
# User46 is friends with User96
# User86 is friends with User96
# User20 is friends with User96
# User34 is friends with User96
# User84 is friends with User96
# User63 is friends with User96
# User100 is friends with User97
# User44 is friends with User97
# User24 is friends with User97
# User89 is friends with User97
# User76 is friends with User97
# User48 is friends with User97
# User65 is friends with User97
# User59 is friends with User97
# User73 is friends with User97
# User13 is friends with User97
# User9 is friends with User97
# User31 is friends with User97
# User69 is friends with User97
# User3 is friends with User97
# User45 is friends with User97
# User61 is friends with User97
# User11 is friends with User97
# User92 is friends with User97
# User22 is friends with User97
# User18 is friends with User97
# User71 is friends with User97
# User33 is friends with User97
# User15 is friends with User97
# User60 is friends with User97
# User21 is friends with User97
# User32 is friends with User97
# User72 is friends with User97
# User17 is friends with User97
# User99 is friends with User98
# User76 is friends with User98
# User93 is friends with User98
# User5 is friends with User98
# User15 is friends with User98
# User14 is friends with User98
# User85 is friends with User98
# User35 is friends with User98
# User35 is friends with User99
# User96 is friends with User99
# User58 is friends with User99
# User29 is friends with User99
# User77 is friends with User99
# User36 is friends with User99
# User78 is friends with User99
# User98 is friends with User99
# User25 is friends with User99
# User26 is friends with User99
# User70 is friends with User99
# User43 is friends with User99
# User2 is friends with User100
# User28 is friends with User100
# User92 is friends with User100
# User22 is friends with User100
# User48 is friends with User100
# User94 is friends with User100
# User12 is friends with User100
# User75 is friends with User100
# User71 is friends with User100
# User26 is friends with User100
# User55 is friends with User100
# User79 is friends with User100
# User40 is friends with User100
# User42 is friends with User100
# User77 is friends with User100
# User91 is friends with User100
# User74 is friends with User100
# User39 is friends with User100
# User97 is friends with User100
# User68 is friends with User100
# User35 is friends with User100
# User90 is friends with User100
# User8 is friends with User100

# %%
from bson import ObjectId


class JSONEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, ObjectId):
            return str(obj)
        return super(JSONEncoder, self).default(obj)


def get_user_from_mongo(user_id):
    cache_key = f"user:{user_id}"
    cached_user = r.get(cache_key)

    if cached_user:
        return json.loads(cached_user)

    user = collection.find_one({"id": user_id})

    if user:
        r.set(cache_key, json.dumps(user, cls=JSONEncoder), ex=3600)

    return user


for x in range(1, 101):
    user_data = get_user_from_mongo(x)
    print(user_data)
# Out:
# {'_id': ObjectId('6659982fe37981682a4d2d78'), 'id': 1, 'name': 'User1', 'friends': [40, 100, 73, 32, 58]}
# {'_id': ObjectId('6659982fe37981682a4d2d79'), 'id': 2, 'name': 'User2', 'friends': [70, 91, 26, 45, 41, 69, 1, 79, 6, 73, 72, 37, 74, 16, 42, 71, 8, 35, 81, 13, 56, 48, 17, 3, 78, 98, 88, 23, 75, 12, 76, 54]}
# {'_id': ObjectId('6659982fe37981682a4d2d7a'), 'id': 3, 'name': 'User3', 'friends': [6, 77, 35, 5, 87, 42, 94]}
# {'_id': ObjectId('6659982fe37981682a4d2d7b'), 'id': 4, 'name': 'User4', 'friends': [7, 51, 76, 21, 88, 86, 26, 38, 62, 45, 29, 11, 34, 58, 23, 50, 46, 55, 27, 65, 53, 30, 41, 69, 22]}
# {'_id': ObjectId('6659982fe37981682a4d2d7c'), 'id': 5, 'name': 'User5', 'friends': [89, 26, 17, 84, 29, 27, 98, 90, 18, 21, 8, 58, 3, 37]}
# {'_id': ObjectId('6659982fe37981682a4d2dd9'), 'id': 98, 'name': 'User98', 'friends': [99, 35, 85, 14, 15, 5, 93, 76]}
# {'_id': ObjectId('6659982fe37981682a4d2dda'), 'id': 99, 'name': 'User99', 'friends': [43, 70, 26, 25, 98, 78, 36, 77, 29, 58, 96, 35]}
# {'_id': ObjectId('6659982fe37981682a4d2ddb'), 'id': 100, 'name': 'User100', 'friends': [8, 90, 35, 68, 97, 39, 74, 91, 77, 42, 40, 79, 55, 26, 71, 75, 12, 94, 48, 22, 92, 28, 2]}

# %%
def get_graph_with_cache():
    cache_key = "graph:friendships"
    cached_graph = r.get(cache_key)

    if cached_graph:
        return json.loads(cached_graph)

    graph_data = []

    with driver.session() as session:
        def fetch_graph(tx):
            result = tx.run("MATCH (u:User)-[:FRIEND]->(f:User) RETURN u.name, f.name")
            for record in result:
                graph_data.append({"user": record['u.name'], "friend": record['f.name']})

        session.execute_read(fetch_graph)

    r.set(cache_key, json.dumps(graph_data), ex=3600)

    return graph_data


graph_data = get_graph_with_cache()
print(graph_data)
# Out:
# [{'user': 'User95', 'friend': 'User1'}, {'user': 'User94', 'friend': 'User1'}, {'user': 'User92', 'friend': 'User1'}, {'user': 'User85', 'friend': 'User1'}, {'user': 'User82', 'friend': 'User1'}, {'user': 'User78', 'friend': 'User1'}, {'user': 'User75', 'friend': 'User1'}, {'user': 'User73', 'friend': 'User1'}, {'user': 'User71', 'friend': 'User1'}, {'user': 'User70', 'friend': 'User1'}, {'user': 'User63', 'friend': 'User1'}, {'user': 'User55', 'friend': 'User1'}, {'user': 'User52', 'friend': 'User1'}, {'user': 'User49', 'friend': 'User1'}, {'user': 'User44', 'friend': 'User1'}, {'user': 'User41', 'friend': 'User1'}, {'user': 'User38', 'friend': 'User1'}, {'user': 'User37', 'friend': 'User1'}, {'user': 'User31', 'friend': 'User1'}, {'user': 'User30', 'friend': 'User1'}, {'user': 'User23', 'friend': 'User1'}, {'user': 'User13', 'friend': 'User1'}, {'user': 'User12', 'friend': 'User1'}, {'user': 'User6', 'friend': 'User1'}, {'user': 'User2', 'friend': 'User1'}, {'user': 'User100', 'friend': 'User2'}, {'user': 'User95', 'friend': 'User2'}, {'user': 'User90', 'friend': 'User2'}, {'user': 'User89', 'friend': 'User2'}, {'user': 'User86', 'friend': 'User2'}, {'user': 'User85', 'friend': 'User2'}, {'user': 'User84', 'friend': 'User2'}, {'user': 'User72', 'friend': 'User2'}, {'user': 'User64', 'friend': 'User2'}, {'user': 'User63', 'friend': 'User2'}, {'user': 'User62', 'friend': 'User2'}, {'user': 'User60', 'friend': 'User2'}, {'user': 'User55', 'friend': 'User2'}, {'user': 'User53', 'friend': 'User2'}, {'user': 'User51', 'friend': 'User2'}, {'user': 'User46', 'friend': 'User2'}, {'user': 'User37', 'friend': 'User2'}, {'user': 'User35', 'friend': 'User2'}, {'user': 'User30', 'friend': 'User2'}, {'user': 'User24', 'friend': 'User2'}, {'user': 'User23', 'friend': 'User2'}, {'user': 'User17', 'friend': 'User2'}, {'user': 'User14', 'friend': 'User2'}, {'user': 'User12', 'friend': 'User2'}, {'user': 'User6', 'friend': 'User2'}, {'user': 'User97', 'friend': 'User3'}, {'user': 'User96', 'friend': 'User3'}, {'user': 'User93', 'friend': 'User3'}, {'user': 'User83', 'friend': 'User3'}, {'user': 'User81', 'friend': 'User3'}, {'user': 'User77', 'friend': 'User3'}, {'user': 'User76', 'friend': 'User3'}, {'user': 'User75', 'friend': 'User3'}, {'user': 'User73', 'friend': 'User3'}, {'user': 'User72', 'friend': 'User3'}, {'user': 'User70', 'friend': 'User3'}, {'user': 'User68', 'friend': 'User3'}, {'user': 'User64', 'friend': 'User3'}, {'user': 'User62', 'friend': 'User3'}, {'user': 'User58', 'friend': 'User3'}, {'user': 'User53', 'friend': 'User3'}, {'user': 'User48', 'friend': 'User3'}, {'user': 'User46', 'friend': 'User3'}, {'user': 'User40', 'friend': 'User3'}, {'user': 'User38', 'friend': 'User3'}, {'user': 'User35', 'friend': 'User3'}, {'user': 'User34', 'friend': 'User3'}, {'user': 'User33', 'friend': 'User3'}, {'user': 'User30', 'friend': 'User3'}, {'user': 'User20', 'friend': 'User3'}, {'user': 'User18', 'friend': 'User3'}, {'user': 'User12', 'friend': 'User3'}, {'user': 'User9', 'friend': 'User3'}, {'user': 'User7', 'friend': 'User3'}, {'user': 'User5', 'friend': 'User3'}, {'user': 'User95', 'friend': 'User4'}, {'user': 'User83', 'friend': 'User4'}, {'user': 'User80', 'friend': 'User4'}, {'user': 'User76', 'friend': 'User4'}, {'user': 'User75', 'friend': 'User4'}, {'user': 'User73', 'friend': 'User4'}, {'user': 'User70', 'friend': 'User4'}, {'user': 'User62', 'friend': 'User4'}, {'user': 'User60', 'friend': 'User4'}, {'user': 'User56', 'friend': 'User4'}, {'user': 'User55', 'friend': 'User4'}, {'user': 'User45', 'friend': 'User4'}, {'user': 'User41', 'friend': 'User4'}, {'user': 'User35', 'friend': 'User4'}, {'user': 'User28', 'friend': 'User4'}, {'user': 'User25', 'friend': 'User4'}, {'user': 'User24', 'friend': 'User4'}, {'user': 'User23', 'friend': 'User4'}, {'user': 'User22', 'friend': 'User4'}, {'user': 'User17', 'friend': 'User4'}, {'user': 'User13', 'friend': 'User4'}, {'user': 'User11', 'friend': 'User4'}, {'user': 'User7', 'friend' ...

# %%
def clear_redis():
    r = redis.Redis(host='localhost', port=6379, db=0)
    r.flushdb()
    print("Redis database has been flushed")


def clear_mongodb():
    client = pymongo.MongoClient("mongodb://localhost:27017/")
    db = client["mydatabase"]
    db.drop_collection("users")
    print("MongoDB 'users' collection has been dropped")


def clear_neo4j():
    uri = "bolt://localhost:7687"
    username = "neo4j"
    password = "password"
    driver = GraphDatabase.driver(uri, auth=(username, password))

    def clear_database(tx):
        tx.run("MATCH (n) DETACH DELETE n")

    with driver.session() as session:
        session.execute_write(clear_database)
    print("Neo4J database has been cleared")


clear_redis()
clear_mongodb()
clear_neo4j()
# Out:
# Redis database has been flushed
# MongoDB 'users' collection has been dropped
# Neo4J database has been cleared
